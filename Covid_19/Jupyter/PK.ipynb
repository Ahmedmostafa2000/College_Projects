# %%
import os
os.chdir("D:\Work flow")

# %%
import pandas as pd
data = pd.read_csv("#1.csv")

# %%
data.head()
# Out:
#    Unnamed: 0 Province/State         Country    Last Update  Confirmed  \
# 0         538            NaN          France  1/2/2020 1:52          6
# 1         548            NaN              UK  1/2/2020 1:52          2
# 2         555          Tibet  Mainland China  1/2/2020 1:52          1
# 3         605            NaN          France  1/2/2020 1:52          6
# 4         617            NaN              UK  1/2/2020 1:52          2
#
#    Deaths  Recovered  nDate
# 0       0          0      2
# 1       0          0      2
# 2       0          0      2
# 3       0          0      2
# 4       0          0      2

# %%
data = data.drop("Unnamed: 0",axis = 1)

# %%
data.head()
# Out:
#   Province/State         Country    Last Update  Confirmed  Deaths  Recovered  \
# 0            NaN          France  1/2/2020 1:52          6       0          0
# 1            NaN              UK  1/2/2020 1:52          2       0          0
# 2          Tibet  Mainland China  1/2/2020 1:52          1       0          0
# 3            NaN          France  1/2/2020 1:52          6       0          0
# 4            NaN              UK  1/2/2020 1:52          2       0          0
#
#    nDate
# 0      2
# 1      2
# 2      2
# 3      2
# 4      2

# %%
len(data["Province/State"].unique())
# Out:
# 57

# %%
data = data.sort_values(by=['Province/State'])

# %%
data.reset_index()
# Out:
#      index Province/State               Country      Last Update  Confirmed  \
# 0      173          Anhui        Mainland China  1/25/2020 12:00         60
# 1      426          Anhui        Mainland China  1/30/2020 21:30        237
# 2      516          Anhui        Mainland China  1/31/2020 19:00        237
# 3      369          Anhui        Mainland China  1/29/2020 21:00        200
# 4      688          Anhui        Mainland China    3/2/2020 0:53        408
# 5       45          Anhui                 China  1/22/2020 12:00          1
# 6      666          Anhui        Mainland China    2/4/2020 0:43        480
# 7      265          Anhui        Mainland China  1/27/2020 20:30        106
# 8       83          Anhui        Mainland China  1/23/2020 12:00          9
# 9      318          Anhui        Mainland China  1/28/2020 23:00        152
# 10     139          Anhui        Mainland China  1/24/2020 12:00         15
# ...

# %%
data = data.set_index(["Country",'Province/State'])

# %%
data.head()
# Out:
#                                    Last Update  Confirmed  Deaths  Recovered  \
# Country        Province/State
# Mainland China Anhui           1/25/2020 12:00         60       0          0
#                Anhui           1/30/2020 21:30        237       0          3
#                Anhui           1/31/2020 19:00        237       0          3
#                Anhui           1/29/2020 21:00        200       0          2
#                Anhui             3/2/2020 0:53        408       0          7
#
#                                nDate
# Country        Province/State
# Mainland China Anhui              25
#                Anhui              30
#                Anhui              31
#                Anhui              29
#                Anhui              36

# %%
china = pd.DataFrame(data.loc[["Mainland China","China"]])

# %%
#data.reset_index(level = 2, inplace = True, col_level = 1)
china = china.sort_values(by=['Country'])

# %%
data.to_csv("#1PK.csv")

# %%
china.to_csv("#1china.csv")
