# %%
import pandas as pd
data = pd.read_csv("combined_csv.csv",index_col = ['Country/Region'])
from matplotlib import pyplot
data.set_index(["Country/Region"])
def determine_country(country):
    data_country = pd.DataFrame(data.loc[[country]])
    data_country = data_country.set_index("Last Update")
    data_country.to_csv("{0}_1603.csv".format(country))
    # %matplotlib inline
    data_country.Confirmed.plot(kind="line")
    return data_country
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\mm\appdata\local\programs\python\python36-32\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Country/Region'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-b4115755353c> in <module>
# ...

# %%
italy_data = determine_country("Italy")

# %%
x = list(data.index.unique())
x.sort()
x
# Out:
# [' Azerbaijan',
#  'Afghanistan',
#  'Albania',
#  'Algeria',
#  'Andorra',
#  'Antigua and Barbuda',
#  'Argentina',
#  'Armenia',
#  'Aruba',
#  'Australia',
#  'Austria',
#  'Azerbaijan',
#  'Bahamas, The',
#  'Bahrain',
#  'Bangladesh',
#  'Barbados',
#  'Belarus',
#  'Belgium',
#  'Benin',
#  'Bhutan',
#  'Bolivia',
#  'Bosnia and Herzegovina',
#  'Brazil',
#  'Brunei',
#  'Bulgaria',
#  'Burkina Faso',
#  'Cambodia',
#  'Cameroon',
#  'Canada',
#  'Cayman Islands',
#  'Central African Republic',
#  'Chad',
#  'Channel Islands',
#  'Chile',
#  'China',
#  'Colombia',
#  'Congo (Brazzaville)',
#  'Congo (Kinshasa)',
#  'Costa Rica',
#  "Cote d'Ivoire",
#  'Croatia',
#  'Cruise Ship',
#  'Cuba',
#  'Curacao',
#  'Cyprus',
#  'Czech Republic',
#  'Czechia',
#  'Denmark',
#  'Djibouti',
#  'Dominican Republic',
#  'Ecuador',
#  'Egypt',
#  'El Salvador',
#  'Equatorial Guinea',
#  'Estonia',
#  'Eswatini',
#  'Ethiopia',
#  'Faroe Islands',
#  'Fiji',
#  'Finland',
#  'France',
# ...

# %%
usa_data = determine_country('US')

# %%
aust_data = determine_country("Australia")

# %%
aust_data.sum()
# Out:
# Confirmed     4208.0000
# Deaths          57.0000
# Latitude     -3685.4635
# Longitude    21793.8494
# Recovered      575.0000
# dtype: float64

# %%
list(italy_data["Confirmed"])[-1]
# Out:
# 41035.0

# %%
usa_data.sum()
# Out:
# Confirmed                                                     48091
# Deaths                                                          891
# Latitude                                                    41182.6
# Longitude                                                  -97718.6
# Province/State    WashingtonWashingtonWashingtonChicagoWashingto...
# Recovered                                                       470
# dtype: object

# %%
aust_data.head()
# Out:
#                Confirmed  Deaths  Latitude  Longitude   Province/State  \
# Last Update
# 1/23/20 17:00        NaN     NaN       NaN        NaN              NaN
# 1/25/20 17:00        4.0     NaN       NaN        NaN              NaN
# 1/26/20 16:00        4.0     NaN       NaN        NaN              NaN
# 1/27/20 23:59        4.0     NaN       NaN        NaN  New South Wales
# 1/27/20 23:59        1.0     NaN       NaN        NaN         Victoria
#
#                Recovered
# Last Update
# 1/23/20 17:00        NaN
# 1/25/20 17:00        NaN
# 1/26/20 16:00        NaN
# 1/27/20 23:59        NaN
# 1/27/20 23:59        NaN

# %%
aust_data.reset_index()
aust_data.sum(level = "Last Update")
# Out:
#                      Confirmed  Deaths  Latitude  Longitude  Recovered
# Last Update
# 1/23/20 17:00              0.0     0.0    0.0000     0.0000        0.0
# 1/25/20 17:00              4.0     0.0    0.0000     0.0000        0.0
# 1/26/20 16:00              4.0     0.0    0.0000     0.0000        0.0
# 1/27/20 23:59              5.0     0.0    0.0000     0.0000        0.0
# 1/28/20 23:00              5.0     0.0    0.0000     0.0000        0.0
# 1/29/20 19:30              5.0     0.0    0.0000     0.0000        0.0
# 1/30/20 16:00              9.0     0.0    0.0000     0.0000        2.0
# 1/31/2020 23:59            9.0     0.0    0.0000     0.0000        2.0
# 2/1/2020 18:12            12.0     0.0    0.0000     0.0000        2.0
# 2020-02-01T18:12:49       60.0     0.0    0.0000     0.0000        8.0
# 2020-02-02T22:33:07       34.0     0.0    0.0000     0.0000        0.0
# 2020-02-04T16:53:03        6.0     0.0    0.0000     0.0000        0.0
# ...
